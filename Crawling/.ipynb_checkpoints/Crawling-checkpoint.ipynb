# %% [markdown]
# # Crawling(scrapying)
# ---
# - web에서 데이터를 프로그램을 통해서 가져오는 작업
#
#
# - web구성하는 언어 - html, css, javascript
#     - html은 웹을 기본 구조를 구성하는 스크립트 언어
#     - css는 웹을 꾸며주는 언어
#     - javascript는 웹이 동적으로 작동하도록 만드는 언어

# %% [markdown]
# ## html
# ---
# - 기본 구조는 태그 - 여는 태그 '<', 닫는 태그 '/>'
# - 태그 계층구조 부모태그, 자식태그, ...
#
# - \<head> 정보... \</head> : 웹의 정보를 담고 있는 태그
# - \<body> 태그... \<body> : 웹에서 눈으로 보는 내용이 들어있는 태그

# %%
# <html>
#     <head>
#         web page meta 정보
    
#     </head>
    
#     <body>                                                    body : 웹에서 눈에 보이는 부분
#         웹페이지에서 보여지는 콘텐츠가 들어가는 부분
#         <p>문단을 나타냅니다</p>                             p : 문단태크
#         <div><h3>제목을 나타냅니다</h3></div>                div : 박스태그   h : 제목태그 (3 : 글자크기)
#     </body>
# </html>

# %%
# <html>
#     <head>
#         web page meta 정보
    
#     </head>
    
#     <body>
#         <table border = 1>                        table : 표를 만드는 태그
#         <tr>                                      tr : 테이블의 행
#             <td>항목</td>                         td : 테이블의 칼럼
#             <td>2013/td>
#             <td>2014</td>
#         </tr>
#         <tr>                                       표 2행
#             <td>항목</td>
#             <td>2013/td>
#             <td>2014</td>
#         </tr>
#     </body>
# </html>

# %%
# <html>
#     <head>
#         <style>                                  style : css 스타일을 조정
#             p {color:blue;}                      p 태그는 blue
#             div {color:red;}                     div 태그는 red
#         </style>
#     </head>
    
#     <body>
#         <p> paragragh1 </p>                       p : 문단을 나누는 태그
#         <p> paragragh2 </p> 
#         <div> div1 </div> 
#     </body>
# </html>

# %%
# <html>
#     <head>
#         <style>
#             #title{color:blue;}     '#'id : 전체 웹문서에서 단 한곳에만 적용 가능      
#             .par{color:red;}         class :  여러 곳에 적용 가능
#         </style>
#     </head>
    
#     <body>
#         <p id=title> paragragh1 </p> 
#         <p class = par> paragragh2 </p> 
#         <div class = par> div1 </div> 
#     </body>
# </html>

# %%
html = '''
<html>
    <head>
        web page meta 정보
    
    </head>
    
    <body>
        <table border = 1>
        <tr>
            <td>항목</td>
            <td>2013</td>
            <td>2014</td>
        </tr>
        <tr>
            <td>항목</td>
            <td>2013</td>
            <td>2014</td>
        </tr>
    </body>
</html>
'''

# %%
html
# Out:
# '\n<html>\n    <head>\n        web page meta 정보\n    \n    </head>\n    \n    <body>\n        <table border = 1>\n        <tr>\n            <td>항목</td>\n            <td>2013</td>\n            <td>2014</td>\n        </tr>\n        <tr>\n            <td>항목</td>\n            <td>2013</td>\n            <td>2014</td>\n        </tr>\n    </body>\n</html>\n'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select('td')
# Out:
# [<td>항목</td>,
#  <td>2013</td>,
#  <td>2014</td>,
#  <td>항목</td>,
#  <td>2013</td>,
#  <td>2014</td>]

# %%
soup.select('td')[1].text
# Out:
# '2013'

# %%
html = """
<body>
<div>
    <div class='snack'>
        <p id='first'> 양파링</p>
        <p id='second'> 새우깡</p>
        <p> 초코파이</p>
        <p class='sweet'> 맛동산 </p>
        
    <div class='icecream'>
        <p> 빵빠레</p>
        <p id='third'> 죠스바</p>
        <p> 꼬깔콘</p>
        <p class='sweet'> 쭈쭈바</p>
    </div>
</div>
</body>
"""

# %%
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# p태그의 텍스트를 모두 출력하시오

# %%
for t in soup.select('p'):
    print(t.text)
# Out:
#  양파링
#  새우깡
#  초코파이
#  맛동산
#  빵빠레
#  죠스바
#  꼬깔콘
#  쭈쭈바

# %% [markdown]
# '양파링'을 출력하시오

# %%
soup.select('p#first')[0].text
# Out:
# ' 양파링'

# %% [markdown]
# 죠스바를 출력하시오

# %%
soup.select('p#third')[0].text
# Out:
# ' 죠스바'

# %% [markdown]
# 맛동산을 출력하시오

# %%
soup.select('p.sweet')[0].text
# Out:
# ' 맛동산 '

# %% [markdown]
# > 네이버 메뉴 크롤링

# %%
import requests      # 웹페이지 가져오는 모듈

# %%
res = requests.get('https://www.naver.com/')

# %%
html = res.text
html
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
path = "#NM_FAVORITE > div.group_nav > ul.list_nav.NM_FAVORITE_LIST > li"

# %%
lis = soup.select(path)

# %%
# <li> ... </li> : 목록을 만드는 태그
# <a href:'http://www.daum.net'> 다음 </a> : 하이퍼링크를 나타내는 태그

# %%
for li in lis:
    print(li.text)
# Out:
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# VIBE
# 책
# 웹툰

# %%
for li in lis:
    print(li.text, li.select('a')[0]['href'])
# Out:
# 사전 https://dict.naver.com/
# 뉴스 https://news.naver.com/
# 증권 https://finance.naver.com/
# 부동산 https://land.naver.com/
# 지도 https://map.naver.com/
# VIBE https://vibe.naver.com/
# 책 https://book.naver.com/
# 웹툰 https://comic.naver.com/

# %%
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0'
res = requests.get(url)

# %%
html = res.text
soup = BeautifulSoup(html, 'html.parser')

# %%
path = "#newsColl > div.cont_divider > ul > li"

# %%
lis = soup.select(path)

# %%
for li in lis:
    print(li.select('a')[1].text)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# 대전시, 빅데이터 활용 '지역사회건강지도' 구축
#  경기도, '2022년 빅데이터위원회, 제1차 회의' 개...
# 경기도,도 빅데이터위원회 개최…올해 경기도 마이데이터 플랫폼 개시
# 빅데이터로 우범 지역 핀셋 관리..서초구, '예측범죄지도' 도입
# 1인 셀러부터 동네 가게 사장님까지 소상공인도 빅데이터 활용 시대
# 산림청 빅데이터 등 과학기술 기반 산불 대응체계 구축
# 다음뉴스

# %%
path = "#newsColl > div.cont_divider > ul > li > div.wrap_cont > a"
tags = soup.select(path)
for tag in tags:
    print(tag.text)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# 대전시, 빅데이터 활용 '지역사회건강지도' 구축
# 경기도 빅데이터위원회 열고 ‘데이터 기반 도정혁신 방안’ 논의
# 경기도,도 빅데이터위원회 개최…올해 경기도 마이데이터 플랫폼 개시
# 빅데이터로 우범 지역 핀셋 관리..서초구, '예측범죄지도' 도입
# 1인 셀러부터 동네 가게 사장님까지 소상공인도 빅데이터 활용 시대
# 산림청 빅데이터 등 과학기술 기반 산불 대응체계 구축
# 1월 식품 상장기업 브랜드 평판 빅데이터 분석..CJ제일제당 > 오리온 > 농심 > 오뚜기

# %% [markdown]
# 제목 : \[투데이 窓\]빅데이터에서 미래를 읽는 통찰력
# URL : http://v.media.daum.net/v/20220119020501044?f=o
# _______________
#
# 출력하기

# %%
# 내가 한 것
path = "#newsColl > div.cont_divider > ul > li"
lis = soup.select(path)
for li in lis:
    print(li.select('a')[1].text)
    print(li.select('a')[0]['href'])
    print('-' * 100)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# http://v.media.daum.net/v/20220119020501044?f=o
# ----------------------------------------------------------------------------------------------------
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# http://v.media.daum.net/v/20220119141604019?f=o
# ----------------------------------------------------------------------------------------------------
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# http://v.media.daum.net/v/20220119111204914?f=o
# ----------------------------------------------------------------------------------------------------
# 대전시, 빅데이터 활용 '지역사회건강지도' 구축
# http://v.media.daum.net/v/20220119101925108?f=o
# ----------------------------------------------------------------------------------------------------
#  경기도, '2022년 빅데이터위원회, 제1차 회의' 개...
# https://cp.news.search.daum.net/p/115196341
# ----------------------------------------------------------------------------------------------------
# 경기도,도 빅데이터위원회 개최…올해 경기도 마이데이터 플랫폼 개시
# ...

# %%
# 강사님
path = "#newsColl > div.cont_divider > ul > li > div.wrap_cont > a"
tags = soup.select(path)
for tag in tags:
    print(tag.text)
    print(tag['href'])
    print('-' * 100)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# http://v.media.daum.net/v/20220119020501044?f=o
# ----------------------------------------------------------------------------------------------------
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# http://v.media.daum.net/v/20220119141604019?f=o
# ----------------------------------------------------------------------------------------------------
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# http://v.media.daum.net/v/20220119111204914?f=o
# ----------------------------------------------------------------------------------------------------
# 대전시, 빅데이터 활용 '지역사회건강지도' 구축
# http://v.media.daum.net/v/20220119101925108?f=o
# ----------------------------------------------------------------------------------------------------
# 경기도 빅데이터위원회 열고 ‘데이터 기반 도정혁신 방안’ 논의
# https://cp.news.search.daum.net/p/115196341
# ----------------------------------------------------------------------------------------------------
# 경기도,도 빅데이터위원회 개최…올해 경기도 마이데이터 플랫폼 개시
# ...

# %% [markdown]
# summary까지 같이 출력하기

# %%
# 내가 한 것
path = "#newsColl > div.cont_divider > ul > li"
lis = soup.select(path)
for li in lis:
    print(li.select('a')[1].text)
    print(li.select('a')[0]['href'])
    print(li.select('p')[0].text)
    print('-' * 100)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# http://v.media.daum.net/v/20220119020501044?f=o
# 새 강자 그룹은 IT 기반 플랫폼을 보유한 기업들이다. 플랫폼의 강점은 데이터다. 데이터가 모이고 유통되는 곳이 바로 플랫폼이다. 데이터는 21세기 원유가 됐고 바야흐로 빅데이터 시대를 맞게 된 것이다. 새해 벽두, 애플은 새 진기록을 세웠다. 1월4일 사상 처음...
# ----------------------------------------------------------------------------------------------------
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# http://v.media.daum.net/v/20220119141604019?f=o
# 尹 큰 타격 없어..부정감성 안정세 SNS에 녹취 풀린 李, 파장 불투명
# ----------------------------------------------------------------------------------------------------
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# http://v.media.daum.net/v/20220119111204914?f=o
# [주간분석] 의혹 제보자 사망..부정감성 수직상승 TV토론·통화 TV방송 이슈 뜨며 빠른 하락 전환'김건희' 논란 촉각 세운 尹, 부정감성 안정 유지단일화 한복판 安, 3자구도 굳히기 정중동 행보
# ----------------------------------------------------------------------------------------------------
# 대전시, 빅데이터 활용 '지역사회건강지도' 구축
# http://v.media.daum.net/v/20220119101925108?f=o
# ...

# %%
# 강사님
path = "#newsColl > div.cont_divider > ul > li"
tags = soup.select(path)
for tag in tags:
    print(tag.select('a.tit_main')[0].text)
    print(tag.select('a.tit_main')[0]['href'])
    print(tag.select('p.desc')[0].text)
    print('-' * 100)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# http://v.media.daum.net/v/20220119020501044?f=o
# 새 강자 그룹은 IT 기반 플랫폼을 보유한 기업들이다. 플랫폼의 강점은 데이터다. 데이터가 모이고 유통되는 곳이 바로 플랫폼이다. 데이터는 21세기 원유가 됐고 바야흐로 빅데이터 시대를 맞게 된 것이다. 새해 벽두, 애플은 새 진기록을 세웠다. 1월4일 사상 처음...
# ----------------------------------------------------------------------------------------------------
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# http://v.media.daum.net/v/20220119141604019?f=o
# 그리고 지난 한 주간 온라인상 대선 관련 민심, 관심의 흐름은 어떻게 전개되고 있을까요. JTBC가 기획ㆍ개발한 빅데이터 분석 플랫폼 'JTBC빅데이터랩'이 실시간으로, 그리고 한 주간 누적으로 관심과 호감의 변화 양상을 추적합니다. 지난 16일 저녁 국민의힘...
# ----------------------------------------------------------------------------------------------------
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# http://v.media.daum.net/v/20220119111204914?f=o
# 언급량이 늘어났습니다. 'TV토론'과 'TV방송', 이 두 키워드가 어떻게 한 주간 대선판에서 작동했는지 함께 살펴보겠습니다. JTBC빅데이터랩은 뉴스ㆍ커뮤니티ㆍ블로그 등 온라인상의 민심 동향을 추적해 분석하고 있습니다. 일주일 누적 데이터부터 보겠습니다...
# ...

# %%
tags[0]
# Out:
# <li> <div class="wrap_thumb" id="news_img_0"> <a class="thumb" href="http://v.media.daum.net/v/20220119020501044?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26XmtmA0ZgbPEoqFp6&amp;pg=1&amp;r=1&amp;p=1&amp;rc=10&amp;e1=16gmjhh-4e7TNHMCYw&amp;e3=0&amp;ext=dsid=26XmtmA0ZgbPEoqFp6", event, {"cpid": {"value": "16gmjhh-4e7TNHMCYw"}});' target="_blank"> <img alt="" class="thumb_img" data-size="80x80" height="80" onerror="SF.errorImage(this)" src="https://search1.daumcdn.net/thumb/P200x200/?fname=https%3A%2F%2Fsearch3.kakaocdn.net%2Fargon%2F200x200_85_c%2FEF4A8RgR1BG0" width="80"/> </a> </div> <div class="wrap_cont"> <a class="tit_main fn_tit_u" href="http://v.media.daum.net/v/20220119020501044?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26XmtmA0ZgbPEoqFp6&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16gmjhh-4e7TNHMCYw&amp;e3=0&amp;ext=dsid=26XmtmA0ZgbPEoqFp6", event, {"cpid": {"value": "16gmjhh-4e7TNHMCYw"}});' target="_blank">[투데이 窓]<b>빅</b><b>데이터</b>에서 미래를 읽는 통찰력</a> <p class="desc">새 강자 그룹은 I
# ...

# %% [markdown]
# 검색어를 입력 받은 후 해당 검색어로 다음 뉴스 페이지에서 검색한 결과의 제목, url, summary를 크롤링

# %%
# 내가 한 것
url = "https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q="

# %%
search = input()
res = requests.get(url+search)
html = res.text
soup = BeautifulSoup(html, 'html.parser')
path = "#newsColl > div.cont_divider > ul > li"
lis = soup.select(path)
for li in lis:
    print(li.select('a')[1].text)
    print(li.select('a')[0]['href'])
    print(li.select('p')[0].text)
    print('-' * 100)
# Out:
# 아이유
# [MK뮤직] 서른, 아이유
# http://v.media.daum.net/v/20220111070305913?f=o
# 아이유. 사진｜골든디스크어워즈 사무국 2018년, 열다섯 소녀로 대중 앞에 처음 나선 가수 아이유(본명 이지은)가 어느덧 서른이 됐다. 누군가에겐 그저 격세지감일 수도 있지만, 정신없이 달린 10대와 치열하게 쌓아올린 20대를 아주 옹골지게 꽉 닫은 아이유는...
# ----------------------------------------------------------------------------------------------------
# 이근철 "제자 아이유, 영어 이름=릴리..정경호, 달려와서 감사 인사" ('옥문아들')[MD리뷰]
# http://v.media.daum.net/v/20220119054006158?f=o
# [마이데일리 = 강다윤 기자] 영어교육전문가 이근철이 가수 아이유, 배우 김상경, 정경호와의 인연을 전했다. 18일 방송된 KBS 2TV '옥탑방의 문제아들'에서는 최근 미국 코미디쇼에 진출한 '글로벌 코미디언' 김영철과 '스타들의 영어 선생님' 이근철이 출연했다...
# ----------------------------------------------------------------------------------------------------
# 아이유 화보, 물오른 여신 미모+다채로운 매력..이러니 반할 수 밖에
# https://cp.news.search.daum.net/p/115200775
# 브레이크뉴스 박동제 기자= 가수 겸 배우 아이유(이지은)가 화보를 통해 물오른 여신 미모를 자랑했다. 19일 글로벌 스포츠 브랜드 뉴발란스(NEW BALANCE)는 브랜드 엠베서더 아이유와 함께한 2022년 새로운 일상 캠페인을 공개했다. 뉴발란스는 아이유를 브랜드...
# ...

# %%
# 강사님
url = "https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q={}"
search_kw = input('검색할 단어를 입력하세요: ')
url = url.format(search_kw)
# Out:
# 검색할 단어를 입력하세요: 빅데이터

# %%
res = requests.get(url)
html = res.text
soup = BeautifulSoup(html, 'html.parser')
path = "#newsColl > div.cont_divider > ul > li"
tags = soup.select(path)

# %%
len(tags)           # 뉴스 목록 페이지당 10개
# Out:
# 10

# %%
title = tags[9].select('a.tit_main')[0].text
href_ = tags[9].select('a.tit_main')[0]['href']
summary = tags[9].select('p.desc')[0].text

# %%
for tag in tags:
    print(tag.select('a.tit_main')[0].text)
    print(tag.select('a.tit_main')[0]['href'])
    print(tag.select('p.desc')[0].text)
    print('-'*100)
# Out:
# [투데이 窓]빅데이터에서 미래를 읽는 통찰력
# http://v.media.daum.net/v/20220119020501044?f=o
# 새 강자 그룹은 IT 기반 플랫폼을 보유한 기업들이다. 플랫폼의 강점은 데이터다. 데이터가 모이고 유통되는 곳이 바로 플랫폼이다. 데이터는 21세기 원유가 됐고 바야흐로 빅데이터 시대를 맞게 된 것이다. 새해 벽두, 애플은 새 진기록을 세웠다. 1월4일 사상 처음...
# ----------------------------------------------------------------------------------------------------
# 통화 방송 후 사흘.. 관심도 李 46 vs 尹 54 l 빅데이터랩
# http://v.media.daum.net/v/20220119141604019?f=o
# 그리고 지난 한 주간 온라인상 대선 관련 민심, 관심의 흐름은 어떻게 전개되고 있을까요. JTBC가 기획ㆍ개발한 빅데이터 분석 플랫폼 'JTBC빅데이터랩'이 실시간으로, 그리고 한 주간 누적으로 관심과 호감의 변화 양상을 추적합니다. 지난 16일 저녁 국민의힘...
# ----------------------------------------------------------------------------------------------------
# 악재 뜨면 이슈로 맞불.. 李 이번엔 'TV토론 카드'?ㅣ빅데이터랩
# http://v.media.daum.net/v/20220119111204914?f=o
# 언급량이 늘어났습니다. 'TV토론'과 'TV방송', 이 두 키워드가 어떻게 한 주간 대선판에서 작동했는지 함께 살펴보겠습니다. JTBC빅데이터랩은 뉴스ㆍ커뮤니티ㆍ블로그 등 온라인상의 민심 동향을 추적해 분석하고 있습니다. 일주일 누적 데이터부터 보겠습니다...
# ...

# %% [markdown]
# 함수 ver.

# %%
def crawling_daum_news():
    
    url = "https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q={}"
    search_kw = input('검색할 단어를 입력하세요: ')
    url = url.format(search_kw)
    
    res = requests.get(url)
    html = res.text
#     html = requests.get(url)
    soup = BeautifulSoup(html, 'html.parser')
    
    path = "#newsColl > div.cont_divider > ul > li"
    tags = soup.select(path)
    
    for tag in tags:
        print(tag.select('a.tit_main')[0].text)
        print(tag.select('a.tit_main')[0]['href'])
        print(tag.select('p.desc')[0].text)
        print('-'*100)
        print()

# %%
crawling_daum_news()
# Out:
# 검색할 단어를 입력하세요: 아이유
# [MK뮤직] 서른, 아이유
# http://v.media.daum.net/v/20220111070305913?f=o
# 아이유. 사진｜골든디스크어워즈 사무국 2018년, 열다섯 소녀로 대중 앞에 처음 나선 가수 아이유(본명 이지은)가 어느덧 서른이 됐다. 누군가에겐 그저 격세지감일 수도 있지만, 정신없이 달린 10대와 치열하게 쌓아올린 20대를 아주 옹골지게 꽉 닫은 아이유는...
# ----------------------------------------------------------------------------------------------------
#
# 이근철 "제자 아이유, 영어 이름=릴리..정경호, 달려와서 감사 인사" ('옥문아들')[MD리뷰]
# http://v.media.daum.net/v/20220119054006158?f=o
# [마이데일리 = 강다윤 기자] 영어교육전문가 이근철이 가수 아이유, 배우 김상경, 정경호와의 인연을 전했다. 18일 방송된 KBS 2TV '옥탑방의 문제아들'에서는 최근 미국 코미디쇼에 진출한 '글로벌 코미디언' 김영철과 '스타들의 영어 선생님' 이근철이 출연했다...
# ----------------------------------------------------------------------------------------------------
#
# 아이유 화보, 물오른 여신 미모+다채로운 매력..이러니 반할 수 밖에
# https://cp.news.search.daum.net/p/115200775
# 브레이크뉴스 박동제 기자= 가수 겸 배우 아이유(이지은)가 화보를 통해 물오른 여신 미모를 자랑했다. 19일 글로벌 스포츠 브랜드 뉴발란스(NEW BALANCE)는 브랜드 엠베서더 아이유와 함께한 2022년 새로운 일상 캠페인을 공개했다. 뉴발란스는 아이유를 브랜드...
# ...

# %% [markdown]
# 키워드와 크롤링할 페이지 수를 입력받은 후
# 다음 뉴스페이지에서 제목, URL, summary, 언론사, 시간 크롤링해서 출력하는 함수

# %%
def crawling_daum_news(kw = input(), page_num = int(input())):
    try:
        for i in range(1, page_num+1):
            url = "https://search.daum.net/search?nil_suggest=btn&w=news&DA=SBC&q={}&p={}"
            url = url.format(kw,i)

            res = requests.get(url)
            html = res.text
            soup = BeautifulSoup(html, 'html.parser')
            path = "#newsColl > div.cont_divider > ul > li"
            lis = soup.select(path)

            for li in lis:
                print(li.select('a')[1].text)
                print(li.select('a')[0]['href'])
                print(li.select('p')[0].text)
                print(li.select('span')[1].text)
                print(li.select('span')[2].text)
                print('-' * 100)
    except:
        return
    
crawling_daum_news()
# Out:
# 리그오브레전드
# 2
# "3일 만에 조회 수 1000만"..리그오브레전드 시네마틱 흥행
# http://v.media.daum.net/v/20220114083002369?f=o
# 2020년 공개 영상은 1억2000만 조회수 기록해게임 흥행뿐만 아니라 IP 확장으로도 이어져
# 뉴스1
# 2022.01.14
# ----------------------------------------------------------------------------------------------------
# [오마이포토] '리그오브레전드' 대회 관전하는 윤석열-이준석
# http://v.media.daum.net/v/20220112213001960?f=o
# [오마이포토 기자] ▲ [오마이포토] '리그오브레전드' 대회 관전하는 윤석열-이준석 ⓒ 국회사진취재단 국민의힘 윤석열 대선후보와 이준석 대표가 12일 서울시 종로구 그랑서울 타워1에서 온라인 게임 '리그오브레전드' 대회인 2022 LCK 스프링 개막전을 관전하고...
# 오마이뉴스
# 2022.01.12
# ----------------------------------------------------------------------------------------------------
# 라이엇 "올해 리그오브레전드 대규모 패치 없다"
# http://v.media.daum.net/v/20220113085700347?f=o
# 올해 리그오브레전드(롤·LoL) e스포츠는 게임 개발사의 패치로 인한 시즌 도중 큰 변화는 없을 전망이다. 라이엇 게임즈의 나즈 알레타하 e스포츠 총괄은 11일 ‘제4회 글로벌 e스포츠 경쟁력 강화를 위한 연속 심포지움’에서 “시즌을 치르다 대회 규칙을 바꾸는...
# MK스포츠
# 2022.01.13
# ----------------------------------------------------------------------------------------------------
# ...

# %%
url = "https://search.daum.net/search?nil_suggest=btn&w=news&DA=SBC&q={}&p={}"
url = url.format('아이유',1)

res = requests.get(url)
html = res.text
soup = BeautifulSoup(html, 'html.parser')
path = "#newsColl > div.cont_divider > ul > li"
lis = soup.select(path)
lis[0].select('span')
# Out:
# [<span class="cont_info"> <span class="f_nb">스타투데이</span> <span class="f_nb">2022.01.11</span> <a class="f_nb" href="http://v.media.daum.net/v/20220111070305913" onclick='smartLog(this, "dc=NNS&amp;d=264LgUWTPH6ED9Nee9&amp;pg=1&amp;r=1&amp;p=3&amp;rc=10&amp;e1=16wobx7hS73qbhOQqn&amp;e3=0&amp;ext=dsid=264LgUWTPH6ED9Nee9", event, {"cpid": {"value": "16wobx7hS73qbhOQqn"}});' target="_blank">다음뉴스</a> </span>,
#  <span class="f_nb">스타투데이</span>,
#  <span class="f_nb">2022.01.11</span>,
#  <span id="newsSQC_t1_0" style="display:none;">10301^http://v.media.daum.net/v/20220111070305913?f=o^264LgUWTPH6ED9Nee9^news^mediaArticle^%EC%95%84%EC%9D%B4%EC%9C%A0^264LgUWTPH6ED9Nee9</span>]
